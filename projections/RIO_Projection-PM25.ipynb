# %%
import h5py
import numpy as np
import netCDF4
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib import colors
from matplotlib.colors import from_levels_and_colors
plt.rcParams['figure.figsize'] = 15,8

# import module which makes daily and annual average concentrations from hourly concentrations
import lib_proj_from_cctm_to_rio.cctm_average  as cctm_average
# import module which makes linear interpolation
import lib_proj_from_cctm_to_rio.lin_interpol as linpy

#############################################################################################################################
#choose element and coeficients
#
#
#############################################################################################################################
# choose element
element='pm25' 
# coeficient from the ppbV to \mu g/ m^3 for gasses. In case of particle set coef =1
coef=1

#read cmaq grid
grid_CMAQ=netCDF4.Dataset('/data/mala/GRIDCRO2D_01012015.nc')

# lon, lat from CMAQ grid with appropriate shape 
lon=np.array(grid_CMAQ.variables['LON'][0,0,2:101,2:180])
lat=np.array(grid_CMAQ.variables['LAT'][0,0,2:101,2:180])

############################################################################################################################
#read inputs files, set the paths 
#
#
#############################################################################################################################

#rio hdf5 file base year
file = h5py.File('/media/sf_Share/LifeIP_results_RIO/LifeIP_results_RIO/PM25/2015_RIO_output_daily_average/rio_pm25_da_clc12_47x47_20150101-20151231.h5','r')
#cmaq base year
model_CMAQ=netCDF4.Dataset('/media/sf_Share/TERKA/LIFEIP_Small_PM_2015')
#camx base year
model_CAMX=netCDF4.Dataset('/media/sf_Share/TERKA/Life-MP_ref2015_camxout_avrg.grd02_IL_PMspec.nc')
#cmaq bussines as usual
model_CMAQ_BAU=netCDF4.Dataset('/data/bussines_as_ussual/post_nevnor_PM')
#camx bussines as usual
#model_CAMX_BAU=netCDF4.Dataset('/media/sf_Share/TERKA/Life-MP_ref2015_camxout_avrg.grd02_IL_PMspec.nc')


############################################################################################################################
#prepare CMAQ, CAMX and RIO daily and annual average  concentration, the shapes are adjusted in order to fit all thre models
#
#
############################################################################################################################

#CMAQ base year#############################################################################################################
cmaq_daily=cctm_average.daily(np.array(coef*model_CMAQ.variables[element.upper()][:,0,2:101,2:180]))
cmaq_ann=cctm_average.annual(cmaq_daily)

#CMAQ bussines as ussual####################################################################################################
cmaq_daily_BAU=cctm_average.daily(np.array(coef*model_CMAQ_BAU.variables[element.upper()][:,0,2:101,2:180]))
cmaq_ann_BAU=cctm_average.annual(cmaq_daily_BAU)

#CAMX base year#############################################################################################################
camx_daily=cctm_average.daily(model_CAMX.variables['PM2_5'][:,0,1:100,1:179])
camx_ann=cctm_average.annual(camx_daily)

#CAMX bussines as ussual####################################################################################################
#camx_daily_BAU=cctm_average.daily(model_CAMX_BAU.variables['PM2_5'][:,0,1:100,1:179])
#camx_ann_BAU=cctm_average.annual(camx_daily_BAU)

#rio base year##############################################################################################################
rio_daily=np.array(file['grid/value'][:])
rio_daily=np.reshape(rio_daily,(101,179,365))[1:100,1:]

rio_ann=np.empty((99,178))
rio_ann=np.average(rio_daily[:,:,:], axis=2)

#reshape rio_daily in order to have time variables as first index
rio_reshape=np.empty((365,99,178))

for i in range(0,cmaq_ann.shape[0]):
    for j in range(0,cmaq_ann.shape[1]):
        rio_reshape[:,i,j]=rio_daily[i,j,:] 

rio_daily=rio_reshape

# %%
############################################################################################################################
#CCTM base year - scenario interpolation 3 different methods
#
#
############################################################################################################################
rio_daily_BAU_linear=np.empty((365,99,178))
rio_daily_BAU_exp=np.empty((365,99,178))
rio_daily_BAU_ratio=np.empty((365,99,178))


for i in range(0,cmaq_ann.shape[0]):
    for j in range(0,cmaq_ann.shape[1]):
        #linear interpolation
        m,b,r =linpy.lin_interpol(cmaq_daily[:,i,j], cmaq_daily_BAU[:,i,j])    
        #exponential interpolation
        m_l,b_l,r_l =linpy.lin_interpol(np.log(cmaq_daily[:,i,j]), np.log(cmaq_daily_BAU[:,i,j]))
        b_l=np.exp(b_l)
        for k in range(0,365):
            #linear interpolation
            rio_daily_BAU_linear[k,i,j]=rio_daily[k,i,j]*m+b
            #exponential interpolation according Viaene Peter script delta
            rio_daily_BAU_exp[k,i,j]=b_l*rio_daily[k,i,j]**m_l
            #using cctm_scenario/cctm_base_year ratio for rio scenario
            rio_daily_BAU_ratio[k,i,j]=rio_daily[k,i,j]*(cmaq_daily_BAU[k,i,j]/cmaq_daily[k,i,j])

rio_ann_BAU_linear=np.average(rio_daily_BAU_linear[:,:,:], axis=0)
rio_ann_BAU_exp=np.average(rio_daily_BAU_exp[:,:,:], axis=0)  
rio_ann_BAU_ratio=np.average(rio_daily_BAU_ratio[:,:,:], axis=0)

# %% [markdown]
# PLOT ANNUAL CONCENTRATION GRAPHS AND DIFFERENCES

# %%
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann,cmap=plt.cm.jet,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('RIO base year annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close() 
#################################################################################################################
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann_BAU_ratio,cmap=plt.cm.jet,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('RIO (RATIO) bus. as usual year annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close() 
#################################################################################################################
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann_BAU_linear,cmap=plt.cm.jet,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('RIO (LINEAR) bus. as usual year annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close() 
##################################################################################################################
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann_BAU_exp,cmap=plt.cm.jet,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('RIO (EXPONENTIAL) bus. as usual year annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close() 







cmap, norm = from_levels_and_colors([-45,-30,-20,-10,-5,-2,-1,-0.5,-0.2,0.2], ['black','navy','blue', 'deepskyblue','lightgreen','yellow','orange','red','silver'])
################################################################################################################
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann_BAU_linear-rio_ann,cmap=cmap,norm=norm,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('DIFF: RIO (LINEAR) bus. as usual - RIO base year  annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close() 
######################################################################################################################
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann_BAU_exp-rio_ann,cmap=cmap,norm=norm,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('DIFF: RIO (EXPONENTIAL) bus. as usual -RIO base year annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close() 
######################################################################################################################
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann_BAU_ratio-rio_ann,cmap=cmap,norm=norm,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('DIFF: RIO (RATIO) bus. as usual - RIO base year annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close() 





cmap, norm = from_levels_and_colors([-0.5,0.5,1,2,4,6,8,10,12], ['silver','navy','blue', 'deepskyblue','lightgreen','yellow','orange','red'])
######################################################################################################################
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann_BAU_linear-rio_ann_BAU_exp,cmap=cmap,norm=norm,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('DIFF: RIO (LINEAR)-RIO (EXPONENTIAL) bus. as usual year annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close() 
######################################################################################################################
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann_BAU_ratio-rio_ann_BAU_linear,cmap=cmap,norm=norm,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('DIFF: RIO (RATIO)-RIO (LINEAR) bus. as usual year annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close() 
######################################################################################################################
mapb=Basemap(projection='lcc',lat_1=46.24470138549805,lat_2=46.24470138549805,lat_0=49.375,lon_0=17.0,width=832900,height=446351,resolution='i')
mapb.drawcountries()

# choose one of the two style of the plot
mapb.pcolormesh(lon,lat,rio_ann_BAU_ratio-rio_ann_BAU_exp,cmap=cmap,norm=norm,latlon=True) 
#mapb.contourf(lon,lat,dic_ann[i],cmap=plt.cm.jet,latlon=True,norm=colors.LogNorm()) 

plt.colorbar(label='$\mu g /m^3$')
plt.title('DIFF: RIO (RATIO)-RIO (EXP) bus. as usual year annual average concentration of {0} in $\mu g /m^3$'.format(element))
plt.show()
plt.close()
